# %% [markdown]
# # 课件说明

# %% [markdown]
# #### <font color=red>由于原始课件部分代码有些bug，故对寒老师的课件进行了整理和代码调试，你可以点击下方课程大纲中的链接进行相关内容的跳转。</font>

# %% [markdown]
# ## 第一阶段：从零开始搭建音乐推荐系统
#
# ### 第一课 [项目背景与数据准备](./lesson1.ipynb)
#
# 知识点1： 项目前期背景介绍（数据及算法），Surprise库介绍
#
# 知识点2： 音乐推荐系统 -(网易云音乐歌单数据获取及分析)
#
# 知识点3： 音乐推荐系统 -(将网易云音乐歌单数据文件解析为推荐系统格式的数据moveielens datasets,并介绍了推荐系统离线与在线的实现)
#
# ### 第二课 [模型构建与算法调参](./lesson2.ipynb)
#
# 知识点1： 建模及评估
#
# 知识点2： Surprise示例
#
# 知识点3： 载入自建数据集
#
# 知识点4： 算法调参
#
# ### 第三课 [基于movelens数据集的推荐预测](./lesson3.ipynb)
#
# 知识点1： movelens数据集上进行协同过滤构建模型并进行预测
#
# ### 第四课 [基于网易云音乐数据的推荐预测](./lesson4.ipynb)
#
# 知识点1： 网易云音乐数据集上进行协同过滤构建模型并进行预测
#
# 知识点2： 矩阵分解预测和不同推荐算法评估的介绍

# %% [markdown]
# ## 第二阶段：项目进阶-NLP场景与海量数据场景下的推荐
#
# ### 第五课 [word2vec简介与Song2Vec实现](./lesson5.ipynb)
#
# 知识点1： 课程简介
#
# 知识点2： NLP场景中one-hot与word2vec简介,以及Python库gensim
#
# 知识点3： Song2Vec实现
#
# ### 第六课 [冷启动问题与用户兴趣预测问题](./lesson6.ipynb)
#
# 知识点1： 冷启动问题
#
# 知识点2： 用户兴趣预测问题
#
# ### 第七课 [使用Tensorflow实现基于矩阵分解的推荐系统](./lesson7.ipynb)
#
# 知识点1： 矩阵分解与LFM 回顾
#
# 知识点2： 使用Tensorflow实现基于矩阵分解的推荐系统
#
# ### 第八课 基于Spark的协同过滤算法实现
#
# 知识点1： pyspark 协同过滤（包括user-based和item-based协同过滤）
#
# 知识点2： 基于spark中ALS的推荐系统，针对movielens中电影打分数据做推荐
#
# #### [第八课 课件一](./lesson8-1.ipynb)
#
# #### [第八课 课件二](./lesson8-2.ipynb)
#
# #### [第八课 课件三](./lesson8-3.ipynb)

# %% [markdown]
# # 课件下载

# %% [markdown]
# 按照如图操作下载压缩包即可，包含了所有课件内容

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 下图中的 recommendation_system_codes.zip 是寒老师讲课用的原始课件压缩包，目前已上传至云平台，有需要的同学可以按照图示方法进行下载。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 环境配置

# %% [markdown]
# ###  <font color=red>若要在自己的 windows 笔记本上运行代码，可以参考如下方法配置环境：</font>

# %% [markdown]
# （1） 安装 Anaconda，并配置环境变量，Anaconda [下载地址](https://pan.baidu.com/s/1VPZTfmInaL1JJmEyyBbLEg)，提取码：ayt3
#
# （2）更换 Anaconda 的镜像源，命令行输入：
#     - conda config --add channels https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free/
#     - conda config --set show_channel_urls yes
# （3）删除目录 C:\Users\\<你的用户名> 下配置文件.condarc中的-default
#
# ![image.png](attachment:image.png)
#
# （4）安装 Surprise 库，命令行输入：conda install scikit-surprise
#
# （5）升级 pip，命令行输入： python -m pip install --upgrade pip
#
# （6）安装 gensim 库，命令行输入：pip install gensim
#
# （7）安装tensorflow 库，命令行输入：pip install tensorflow==1.4.0
#
# （8）安装 pyspark 库，命令行输入：pip install pyspark
#
# （9）下载 JDK 并解压，JDK [下载地址](https://pan.baidu.com/s/1ma5UTNRFR7qHo9tQcQqRCQ)，提取码：1hu0
#
# （10）下载 Hadoop 并解压，Hadoop [下载地址](https://pan.baidu.com/s/1yhAXXelZ57rbSfByOXA14g)，提取码：2x1v
#
# （11）下载 Spark 并解压，Spark [下载地址](https://pan.baidu.com/s/176cEKkmwk8LhBBh94HmfUg )，提取码：izks

# %% [markdown]
# ### <font color=red>注：spark部分的内容不在考试范围内，且部分代码暂未调试成功，故上述的 (8)-(11) 可以根据自己的情况选择性安装</font>

# %% [markdown]
# ### JDK、Hadoop、Spark 解压后需要配置环境变量
#
# 1. windows上环境变量设置：右键我的电脑==》属性==》高级系统设置==》环境变量==》系统变量
# 2. 配置 jdk 环境变量
#     - 新建系统变量JAVA_HOME,设置值为"JDK解压路径"
#     - 编辑系统变量PATH，添加 %JAVA_HOME%\bin;%JAVA_HOME%\jre\bin;
# 3. 配置 hadoop 环境变量
#     - 新建系统变量HADOOP_HOME,设置值="hadoop解压路径"
#     - 编辑系统变量PATH，添加 %HADOOP_HOME%\bin;
# 4. 配置 spark 环境变量：
#     - 新建系统变量SPARK_HOME,设置值为"spark解压路径"
#     - 编辑系统变量PATH，添加 %SPARK_HOME%\bin;
# 5. 验证安装，命令行输入如下命令，若可以显示出对应版本信息，则说明安装成功
#     - java -version
#     - hadoop version
#     - pyspark --version
